# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), '..'))
from src.data.data_loader import load_raw_data, basic_data_info, save_processed_data

# %% [markdown]
# # Load Data and Describe

# %%
df_raw = load_raw_data(file_path='../../data/raw/raw_data.csv')
df_dict = load_raw_data(file_path='../../data/raw/raw_data_description.csv')
# Out:
# 2025-08-05 17:20:48,837 - src.data.data_loader - INFO - Successfully loaded 48665 rows from ../../data/raw/raw_data.csv
# 2025-08-05 17:20:48,845 - src.data.data_loader - INFO - Successfully loaded 41 rows from ../../data/raw/raw_data_description.csv

# %%
basic_data_info(df_dict)
# Out:
# {'shape': (41, 2),
#  'columns': ['attribute', 'description'],
#  'dtypes': {'attribute': dtype('O'), 'description': dtype('O')},
#  'missing_values': {'attribute': 0, 'description': 0},
#  'memory_usage': 5756}

# %%
basic_data_info(df_raw)
# Out:
# {'shape': (48665, 41),
#  'columns': ['cd_advertise',
#   'cd_client',
#   'cd_type_individual',
#   'priority',
#   'leads',
#   'views',
#   'phone_clicks',
#   'cd_vehicle_brand',
#   'cd_model_vehicle',
#   'cd_version_vehicle',
#   'year_model',
#   'zip_2dig',
#   'city_state',
#   'vl_advertise',
#   'n_photos',
#   'km_vehicle',
#   'vl_market',
#   'flg_single_owner',
#   'flg_lincese',
#   'flg_tax_paid',
#   'flg_all_dealership_services',
#   'flg_all_dealership_schedule_vehicle',
#   'flg_factory_warranty',
#   'flg_armored',
#   'flg_trade_in',
#   'flg_pcd',
#   'fuel_type',
#   'transmission_type',
#   'n_doors',
#   'flg_alarm',
#   'flg_airbag',
#   'flg_heater',
#   'flg_leather_seats',
#   'flg_air_conditioning',
#   'flg_abs',
#   'flg_rear_defogger',
#   'flg_electric_locks',
#   'flg_electric_windows',
#   'flg_alloy_wheels',
#   'flg_rain_sensor',
#   'flg_parking_sensor'],
#  'dtypes': {'cd_advertise': dtype('int64'),
#   'cd_client': dtype('int64'),
#   'cd_type_individual': dtype('int64'),
#   'priority': dtype('int64'),
#   'leads': dtype('int64'),
#   'views': dtype('int64'),
#   'phone_clicks': dtype('int64'),
#   'cd_vehicle_brand': dtype('int64'),
#   'cd_model_vehicle': dtype('int64'),
#   'cd_version_vehicle': dtype('int64'),
#   'year_model': dtype('int64'),
#   'zip_2dig': dtype('int64'),
#   'city_state': dtype('O'),
#   'vl_advertise': dtype('float64'),
#   'n_photos': dtype('int64'),
#   'km_vehicle': dtype('int64'),
#   'vl_market': dtype('float64'),
#   'flg_single_owner': dtype('int64'),
#   'flg_lincese': dtype('int64'),
#   'flg_tax_paid': dtype('float64'),
#   'flg_all_dealership_services': dtype('float64'),
#   'flg_all_dealership_schedule_vehicle': dtype('int64'),
#   'flg_factory_warranty': dtype('float64'),
#   'flg_armored': dtype('int64'),
#   'flg_trade_in': dtype('int64'),
#   'flg_pcd': dtype('float64'),
#   'fuel_type': dtype('O'),
#   'transmission_type': dtype('O'),
#   'n_doors': dtype('float64'),
#   'flg_alarm': dtype('O'),
#   'flg_airbag': dtype('O'),
#   'flg_heater': dtype('O'),
#   'flg_leather_seats': dtype('O'),
#   'flg_air_conditioning': dtype('O'),
#   'flg_abs': dtype('O'),
#   'flg_rear_defogger': dtype('O'),
#   'flg_electric_locks': dtype('O'),
#   'flg_electric_windows': dtype('O'),
#   'flg_alloy_wheels': dtype('O'),
#   'flg_rain_sensor': dtype('O'),
#   'flg_parking_sensor': dtype('O')},
#  'missing_values': {'cd_advertise': 0,
#   'cd_client': 0,
#   'cd_type_individual': 0,
#   'priority': 0,
#   'leads': 0,
#   'views': 0,
#   'phone_clicks': 0,
#   'cd_vehicle_brand': 0,
#   'cd_model_vehicle': 0,
#   'cd_version_vehicle': 0,
#   'year_model': 0,
#   'zip_2dig': 0,
#   'city_state': 0,
#   'vl_advertise': 0,
#   'n_photos': 0,
#   'km_vehicle': 0,
#   'vl_market': 6217,
#   'flg_single_owner': 0,
#   'flg_lincese': 0,
#   'flg_tax_paid': 312,
#   'flg_all_dealership_services': 312,
#   'flg_all_dealership_schedule_vehicle': 0,
#   'flg_factory_warranty': 312,
#   'flg_armored': 0,
#   'flg_trade_in': 0,
#   'flg_pcd': 312,
#   'fuel_type': 1,
#   'transmission_type': 1,
#   'n_doors': 1,
#   'flg_alarm': 1,
#   'flg_airbag': 8,
#   'flg_heater': 1,
#   'flg_leather_seats': 1,
#   'flg_air_conditioning': 1,
#   'flg_abs': 1,
#   'flg_rear_defogger': 1,
#   'flg_electric_locks': 1,
#   'flg_electric_windows': 1,
#   'flg_alloy_wheels': 1,
#   'flg_rain_sensor': 1,
#   'flg_parking_sensor': 1},
#  'memory_usage': 48606640}

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48665 entries, 0 to 48664
# Data columns (total 41 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   cd_advertise                         48665 non-null  int64
#  1   cd_client                            48665 non-null  int64
#  2   cd_type_individual                   48665 non-null  int64
#  3   priority                             48665 non-null  int64
#  4   leads                                48665 non-null  int64
#  5   views                                48665 non-null  int64
#  6   phone_clicks                         48665 non-null  int64
#  7   cd_vehicle_brand                     48665 non-null  int64
#  8   cd_model_vehicle                     48665 non-null  int64
#  9   cd_version_vehicle                   48665 non-null  int64
#  10  year_model                           48665 non-null  int64
#  11  zip_2dig                             48665 non-null  int64
#  12  city_state                           48665 non-null  object
#  13  vl_advertise                         48665 non-null  float64
#  14  n_photos                             48665 non-null  int64
#  15  km_vehicle                           48665 non-null  int64
#  16  vl_market                            42448 non-null  float64
#  17  flg_single_owner                     48665 non-null  int64
#  18  flg_lincese                          48665 non-null  int64
#  19  flg_tax_paid                         48353 non-null  float64
#  20  flg_all_dealership_services          48353 non-null  float64
#  21  flg_all_dealership_schedule_vehicle  48665 non-null  int64
#  22  flg_factory_warranty                 48353 non-null  float64
#  23  flg_armored                          48665 non-null  int64
#  24  flg_trade_in                         48665 non-null  int64
#  25  flg_pcd                              48353 non-null  float64
#  26  fuel_type                            48664 non-null  object
#  27  transmission_type                    48664 non-null  object
#  28  n_doors                              48664 non-null  float64
#  29  flg_alarm                            48664 non-null  object
#  30  flg_airbag                           48657 non-null  object
#  31  flg_heater                           48664 non-null  object
#  32  flg_leather_seats                    48664 non-null  object
#  33  flg_air_conditioning                 48664 non-null  object
#  34  flg_abs                              48664 non-null  object
#  35  flg_rear_defogger                    48664 non-null  object
#  36  flg_electric_locks                   48664 non-null  object
#  37  flg_electric_windows                 48664 non-null  object
#  38  flg_alloy_wheels                     48664 non-null  object
#  39  flg_rain_sensor                      48664 non-null  object
#  40  flg_parking_sensor                   48664 non-null  object
# dtypes: float64(7), int64(19), object(15)
# memory usage: 15.2+ MB

# %%
df_raw.describe()
# Out:
#         cd_advertise     cd_client  cd_type_individual      priority  \
# count   48665.000000  48665.000000        48665.000000  48665.000000
# mean    98293.326518   8804.717374            1.847940      2.601397
# std     56501.266859   7954.688001            0.359083      0.767795
# min         2.000000      1.000000            1.000000      1.000000
# 25%     49530.000000   3630.000000            2.000000      3.000000
# 50%     98030.000000   6778.000000            2.000000      3.000000
# 75%    147292.000000  10504.000000            2.000000      3.000000
# max    195939.000000  38733.000000            2.000000      3.000000
#
#               leads         views  phone_clicks  cd_vehicle_brand  \
# count  48665.000000  48665.000000  48665.000000      48665.000000
# mean       4.416521    446.328737      7.467687         19.282791
# std       11.961256   1105.247844     11.448334         37.630803
# min        0.000000      0.000000      0.000000         -1.000000
# 25%        1.000000     76.000000      2.000000          4.000000
# 50%        1.000000    196.000000      4.000000          5.000000
# 75%        4.000000    452.000000      9.000000         26.000000
# max      364.000000  93608.000000    457.000000        320.000000
#
#        cd_model_vehicle  cd_version_vehicle  ...  flg_single_owner  \
# count      48665.000000        48665.000000  ...      48665.000000
# mean        2063.215658       342632.759149  ...          0.207089
# std         1112.006604        13247.921372  ...          0.405224
# min           -1.000000           -1.000000  ...          0.000000
# 25%          788.000000       342364.000000  ...          0.000000
# 50%         2487.000000       344132.000000  ...          0.000000
# 75%         3202.000000       345633.000000  ...          0.000000
# max         3695.000000       347841.000000  ...          1.000000
#
#         flg_lincese  flg_tax_paid  flg_all_dealership_services  \
# count  48665.000000  48353.000000                 48353.000000
# mean       0.304099      0.401340                     0.151283
# std        0.460030      0.490175                     0.358328
# min        0.000000      0.000000                     0.000000
# 25%        0.000000      0.000000                     0.000000
# 50%        0.000000      0.000000                     0.000000
# 75%        1.000000      1.000000                     0.000000
# max        1.000000      1.000000                     1.000000
#
#        flg_all_dealership_schedule_vehicle  flg_factory_warranty  \
# count                         48665.000000          48353.000000
# mean                              0.066742              0.085786
# std                               0.249577              0.280050
# min                               0.000000              0.000000
# 25%                               0.000000              0.000000
# 50%                               0.000000              0.000000
# 75%                               0.000000              0.000000
# max                               1.000000              1.000000
#
#         flg_armored  flg_trade_in       flg_pcd       n_doors
# count  48665.000000  48665.000000  48353.000000  48664.000000
# mean       0.020836      0.085523      0.000414      3.727170
# std        0.142838      0.279662      0.020334      0.822248
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      4.000000
# 50%        0.000000      0.000000      0.000000      4.000000
# 75%        0.000000      0.000000      0.000000      4.000000
# max        1.000000      1.000000      1.000000      4.000000
#
# [8 rows x 26 columns]

# %%
# Let's now check the percentage of missing values in each column

round(100*(df_raw.isnull().sum()/len(df_raw.index)), 2)
# Out:
# cd_advertise                            0.00
# cd_client                               0.00
# cd_type_individual                      0.00
# priority                                0.00
# leads                                   0.00
# views                                   0.00
# phone_clicks                            0.00
# cd_vehicle_brand                        0.00
# cd_model_vehicle                        0.00
# cd_version_vehicle                      0.00
# year_model                              0.00
# zip_2dig                                0.00
# city_state                              0.00
# vl_advertise                            0.00
# n_photos                                0.00
# km_vehicle                              0.00
# vl_market                              12.78
# flg_single_owner                        0.00
# flg_lincese                             0.00
# flg_tax_paid                            0.64
# flg_all_dealership_services             0.64
# flg_all_dealership_schedule_vehicle     0.00
# flg_factory_warranty                    0.64
# flg_armored                             0.00
# flg_trade_in                            0.00
# flg_pcd                                 0.64
# fuel_type                               0.00
# transmission_type                       0.00
# n_doors                                 0.00
# flg_alarm                               0.00
# flg_airbag                              0.02
# flg_heater                              0.00
# flg_leather_seats                       0.00
# flg_air_conditioning                    0.00
# flg_abs                                 0.00
# flg_rear_defogger                       0.00
# flg_electric_locks                      0.00
# flg_electric_windows                    0.00
# flg_alloy_wheels                        0.00
# flg_rain_sensor                         0.00
# flg_parking_sensor                      0.00
# dtype: float64

# %%
# Get the value counts of all the columns

for column in df_raw:
    print(df_raw[column].astype('category').value_counts(normalize=True).sort_index())
    print('___________________________________________________')
# Out:
# cd_advertise
# 2         0.000021
# 6         0.000021
# 8         0.000021
# 13        0.000021
# 15        0.000021
#             ...
# 195918    0.000021
# 195924    0.000021
# 195930    0.000021
# 195934    0.000021
# 195939    0.000021
# Name: proportion, Length: 48665, dtype: float64
# ___________________________________________________
# cd_client
# 1        0.000164
# 2        0.000473
# 6        0.000185
# 9        0.000226
# 10       0.000021
#            ...
# 38727    0.000021
# 38728    0.000021
# 38729    0.000021
# 38731    0.000021
# 38733    0.000021
# Name: proportion, Length: 16296, dtype: float64
# ___________________________________________________
# cd_type_individual
# 1    0.15206
# 2    0.84794
# Name: proportion, dtype: float64
# ___________________________________________________
# priority
# 1    0.174890
# 2    0.048824
# 3    0.776287
# Name: proportion, dtype: float64
# ___________________________________________________
# leads
# 0      0.218494
# 1      0.480715
# 4      0.133710
# 8      0.058975
# 12     0.032590
#          ...
# 280    0.000062
# 288    0.000021
# 344    0.000041
# 348    0.000021
# 364    0.000041
# Name: proportion, Length: 64, dtype: float64
# ___________________________________________________
# views
# 0        0.006062
# 1        0.014466
# 4        0.017651
# 8        0.014713
# 12       0.012309
#            ...
# 34184    0.000021
# 45048    0.000021
# 71020    0.000021
# 82940    0.000021
# 93608    0.000021
# Name: proportion, Length: 1312, dtype: float64
# ___________________________________________________
# phone_clicks
# 0      0.086859
# 1      0.095942
# 2      0.108353
# 3      0.110202
# 4      0.098798
#          ...
# 279    0.000021
# 312    0.000021
# 332    0.000021
# 342    0.000021
# 457    0.000021
# Name: proportion, Length: 161, dtype: float64
# ___________________________________________________
# cd_vehicle_brand
# -1      0.000041
#  2      0.140614
#  3      0.095264
#  4      0.132621
#  5      0.137265
#           ...
#  299    0.000062
#  304    0.000041
#  311    0.000021
#  313    0.000021
#  320    0.000021
# Name: proportion, Length: 75, dtype: float64
# ___________________________________________________
# cd_model_vehicle
# -1       0.000041
#  643     0.000021
#  645     0.000021
#  646     0.000021
#  650     0.002014
#            ...
#  3680    0.000082
#  3681    0.000021
#  3687    0.000082
#  3692    0.000021
#  3695    0.000021
# Name: proportion, Length: 656, dtype: float64
# ___________________________________________________
# cd_version_vehicle
# -1         0.000041
#  274       0.000021
#  429       0.000041
#  774       0.000021
#  1174      0.000021
#              ...
#  347821    0.000021
#  347823    0.000021
#  347836    0.000021
#  347839    0.000021
#  347841    0.000021
# Name: proportion, Length: 4149, dtype: float64
# ___________________________________________________
# year_model
# -1       0.000041
#  1951    0.000062
#  1952    0.000021
#  1958    0.000021
#  1959    0.000021
#            ...
#  2015    0.126744
#  2016    0.104099
#  2017    0.088873
#  2018    0.096702
#  2019    0.027165
# Name: proportion, Length: 64, dtype: float64
# ___________________________________________________
# zip_2dig
# 0     0.000082
# 1     0.011302
# 2     0.032508
# 3     0.044755
# 4     0.057043
#         ...
# 95    0.012781
# 96    0.006617
# 97    0.002219
# 98    0.000740
# 99    0.002137
# Name: proportion, Length: 98, dtype: float64
# ___________________________________________________
# city_state
# AC_Rio Branco               0.000658
# AL_Arapiraca                0.000062
# AL_Delmiro Gouveia          0.000041
# AL_MaceiÃ³                  0.001459
# AL_Maravilha                0.000021
#                               ...
# SP_Ãlvares Machado         0.000041
# TO_AraguaÃ­na               0.000082
# TO_Gurupi                   0.000103
# TO_Palmas                   0.000062
# TO_ParaÃ­so do Tocantins    0.000021
# Name: proportion, Length: 963, dtype: float64
# ___________________________________________________
# vl_advertise
# 0.0            0.000021
# 3500.0         0.000021
# 4000.0         0.000021
# 4800.0         0.000021
# 4900.0         0.000041
#                  ...
# 122000000.0    0.000041
# 158000000.0    0.000021
# 195000000.0    0.000021
# 218500000.0    0.000021
# 405000000.0    0.000021
# Name: proportion, Length: 4217, dtype: float64
# ___________________________________________________
# n_photos
# 0     0.035200
# 1     0.033063
# 2     0.011548
# 3     0.019069
# 4     0.038118
# 5     0.068838
# 6     0.101408
# 7     0.147149
# 8     0.539279
# 9     0.004007
# 10    0.001048
# 11    0.000493
# 12    0.000288
# 13    0.000103
# 14    0.000062
# 15    0.000021
# 16    0.000123
# 17    0.000103
# 18    0.000021
# 19    0.000021
# 20    0.000041
# Name: proportion, dtype: float64
# ___________________________________________________
# km_vehicle
# 0             0.063824
# 100           0.029754
# 101           0.007603
# 102           0.000082
# 103           0.000123
#                 ...
# 117800000     0.000021
# 999999999     0.000041
# 1000000000    0.000021
# 1111111111    0.000123
# 2147483647    0.000041
# Name: proportion, Length: 15141, dtype: float64
# ___________________________________________________
# vl_market
# 6.292844e+03    0.000024
# 6.335633e+03    0.000024
# 6.342188e+03    0.000024
# 6.400700e+03    0.000024
# 6.479761e+03    0.000024
#                   ...
# 6.864933e+05    0.000024
# 6.922326e+05    0.000024
# 8.520176e+05    0.000024
# 9.212392e+05    0.000024
# 1.111216e+06    0.000024
# Name: proportion, Length: 36130, dtype: float64
# ___________________________________________________
# flg_single_owner
# 0    0.792911
# 1    0.207089
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_lincese
# 0    0.695901
# 1    0.304099
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_tax_paid
# 0.0    0.59866
# 1.0    0.40134
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_all_dealership_services
# 0.0    0.848717
# 1.0    0.151283
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_all_dealership_schedule_vehicle
# 0    0.933258
# 1    0.066742
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_factory_warranty
# 0.0    0.914214
# 1.0    0.085786
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_armored
# 0    0.979164
# 1    0.020836
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_trade_in
# 0    0.914477
# 1    0.085523
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_pcd
# 0.0    0.999586
# 1.0    0.000414
# Name: proportion, dtype: float64
# ___________________________________________________
# fuel_type
# alcool                                     0.002425
# alcool e gas natural                       0.000370
# diesel                                     0.055133
# gas natural                                0.000596
# gasolina                                   0.212169
# gasolina e alcool                          0.723225
# gasolina e eletrico                        0.000596
# gasolina e gas natural                     0.001130
# gasolina, alcool e gas natural             0.004192
# gasolina, alcool, gas natural e benzina    0.000164
# Name: proportion, dtype: float64
# ___________________________________________________
# transmission_type
# CVT                      0.010418
# automatico               0.428777
# automatico sequencial    0.000226
# automatizado             0.002754
# automatizado DCT         0.000226
# manual                   0.555051
# semi-automatico          0.002548
# Name: proportion, dtype: float64
# ___________________________________________________
# n_doors
# 0.0    0.026714
# 2.0    0.078559
# 3.0    0.008857
# 4.0    0.885870
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_alarm
# N    0.380281
# S    0.599704
# Y    0.020015
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_airbag
# N    0.324578
# S    0.655754
# Y    0.019668
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_heater
# N    0.366760
# S    0.614191
# Y    0.019049
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_leather_seats
# N    0.671831
# S    0.316004
# Y    0.012165
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_air_conditioning
# N    0.152844
# S    0.823545
# Y    0.023611
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_abs
# N    0.366513
# S    0.614910
# Y    0.018576
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_rear_defogger
# N    0.369822
# S    0.611479
# Y    0.018700
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_electric_locks
# N    0.154981
# S    0.821470
# Y    0.023549
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_electric_windows
# N    0.160303
# S    0.816373
# Y    0.023323
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_alloy_wheels
# N    0.449367
# S    0.533351
# Y    0.017282
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_rain_sensor
# N    0.911968
# S    0.082258
# Y    0.005774
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_parking_sensor
# N    0.720492
# S    0.279508
# Name: proportion, dtype: float64
# ___________________________________________________

# %% [markdown]
# ## Cleaning and Preprocessing

# %% [markdown]
# ### Creating separated columns for city and state

# %%
# To better understand the data, we will split the column 'city_state' into 
# two separate columns: 'city' and 'state'. With this, we can analyze the leads separately by state and city.

# Creating a new column 'city' and 'state' from 'city_state'
for _,row in df_raw.iterrows():
    str_cs = row['city_state']
    cs_ = str_cs.split('_')
    df_raw.at[_,"city_state"] = str_cs  
    df_raw.at[_,"city"] = cs_[1].strip()
    df_raw.at[_,"state"] = cs_[0].strip()
# Drop the original 'city_state' column
df_raw.drop(columns=['city_state'], inplace=True)

# Function to fix encoding issues in text columns
def fix_encoding(text):
    if isinstance(text, str):
        try:
            return (
                text
                .encode('latin1', errors='replace')
                .decode('utf-8', errors='replace')
            )
        except:
            return text
    return text



df_raw['city'] = df_raw['city'].apply(fix_encoding)

# %% [markdown]
# ### Transforming flag columns to int

# %%
# This block will check if there are any columns that start with 'flg_' and convert them to integers. 
# As we saw in previous analysis these flg columns are categorical variables that indicate the 
# presence of a feature, so we will convert them to integers (1 for 'Y' and 0 for 'N').
for col in df_raw.columns:
    if col.startswith("flg_"):
        df_raw[col] = df_raw[col].fillna(0)
        df_raw[col] = df_raw[col].replace({"S": "Y"}).replace({"Y": 1, "N":0}).astype(int)

# %% [markdown]
# ### Transforming fuel type columns in multiple columns

# %%
df_raw.fuel_type.unique()
# Out:
# array([nan, 'alcool', 'gasolina', 'gasolina e alcool',
#        'gasolina e gas natural', 'diesel',
#        'gasolina, alcool e gas natural', 'gas natural',
#        'alcool e gas natural', 'gasolina e eletrico',
#        'gasolina, alcool, gas natural e benzina'], dtype=object)

# %%
# These type of glimpse you will acquire with experience, but it is always good to check the unique values of a column
# to understand the data better. In this case, we can see that the fuel_type column
# has multiple fuel types in a single string, separated by spaces and commas.
# This is not ideal for analysis, as we want to have each fuel type in a separate column to better 
# understand how the fuel type can influence on the leads

# The goal here is to transform the fuel_type column into multiple columns,
# one for each fuel type as a flag column

# First, we will create a list of unique fuel types and find the unique values in the 'fuel_type' column

df_processed = df_raw.copy()
fuel_types = []
for item in df_processed.fuel_type.unique():
    if isinstance(item, str): # check if item is a string
        # Split the string by spaces and commas, and strip any whitespace
        str_lst = item.split(' ')
        for i in range(len(str_lst)):
            str_lst[i] = str_lst[i].strip().replace(',', '') # remove commas
            if str_lst[i] != 'e': # check if the item is not 'e'
                if str_lst[i] not in fuel_types: # check if the item is not already in the list
                    fuel_types.append(str_lst[i])

print("These are all fuel types:", fuel_types)

# Second, now we know the unique fuel types, we can create a new column for each fuel type
# But first, we need to fix the two type 'natural' and 'gas' to be the same 'natural gas'
fuel_types.remove('natural')
fuel_types.remove('gas')
fuel_types.append('gas natural')

df_processed['fuel_type'] = df_processed['fuel_type'].fillna('')  # Fill NaN values with empty string to avoid errors

# Third, we need to create a new column for each fuel type
for fuel in fuel_types:
    df_processed[f"flg_{fuel.replace(" ", "_")}"] = df_processed['fuel_type'].apply(lambda x: 1 if fuel in x else 0 if x == '' else 0)

# Now we can drop the original fuel_type column
df_processed.drop(columns=['fuel_type'], inplace=True)
# Out:
# These are all fuel types: ['alcool', 'gasolina', 'gas', 'natural', 'diesel', 'eletrico', 'benzina']

# %%
for column in df_processed:
    print(df_processed[column].value_counts(normalize=True).sort_values(ascending=False))
    print('___________________________________________________')
# Out:
# cd_advertise
# 2         0.000021
# 31        0.000021
# 336       0.000021
# 40        0.000021
# 8         0.000021
#             ...
# 195906    0.000021
# 195912    0.000021
# 195918    0.000021
# 195924    0.000021
# 195939    0.000021
# Name: proportion, Length: 48665, dtype: float64
# ___________________________________________________
# cd_client
# 345      0.002343
# 525      0.002034
# 5958     0.001418
# 6246     0.001397
# 8967     0.001315
#            ...
# 770      0.000021
# 31430    0.000021
# 16468    0.000021
# 37985    0.000021
# 38232    0.000021
# Name: proportion, Length: 16296, dtype: float64
# ___________________________________________________
# cd_type_individual
# 2    0.84794
# 1    0.15206
# Name: proportion, dtype: float64
# ___________________________________________________
# priority
# 3    0.776287
# 1    0.174890
# 2    0.048824
# Name: proportion, dtype: float64
# ___________________________________________________
# leads
# 1      0.480715
# 0      0.218494
# 4      0.133710
# 8      0.058975
# 12     0.032590
#          ...
# 348    0.000021
# 220    0.000021
# 212    0.000021
# 128    0.000021
# 140    0.000021
# Name: proportion, Length: 64, dtype: float64
# ___________________________________________________
# views
# 4        0.017651
# 8        0.014713
# 1        0.014466
# 36       0.013254
# 24       0.013110
#            ...
# 12328    0.000021
# 12360    0.000021
# 12388    0.000021
# 12648    0.000021
# 93608    0.000021
# Name: proportion, Length: 1312, dtype: float64
# ___________________________________________________
# phone_clicks
# 3      0.110202
# 2      0.108353
# 4      0.098798
# 1      0.095942
# 0      0.086859
#          ...
# 115    0.000021
# 342    0.000021
# 132    0.000021
# 125    0.000021
# 201    0.000021
# Name: proportion, Length: 161, dtype: float64
# ___________________________________________________
# cd_vehicle_brand
# 2      0.140614
# 5      0.137265
# 4      0.132621
# 3      0.095264
# 30     0.074304
#          ...
# 42     0.000021
# 288    0.000021
# 311    0.000021
# 260    0.000021
# 219    0.000021
# Name: proportion, Length: 75, dtype: float64
# ___________________________________________________
# cd_model_vehicle
# 2848    0.030700
# 740     0.029960
# 1222    0.025110
# 788     0.024946
# 687     0.024617
#           ...
# 1206    0.000021
# 646     0.000021
# 3469    0.000021
# 3155    0.000021
# 3293    0.000021
# Name: proportion, Length: 656, dtype: float64
# ___________________________________________________
# cd_version_vehicle
# 342983    0.010644
# 344558    0.006617
# 344650    0.005713
# 345738    0.005384
# 344067    0.005281
#             ...
# 339144    0.000021
# 311423    0.000021
# 338630    0.000021
# 340627    0.000021
# 342940    0.000021
# Name: proportion, Length: 4149, dtype: float64
# ___________________________________________________
# year_model
#  2015    0.126744
#  2014    0.118936
#  2016    0.104099
#  2013    0.102805
#  2018    0.096702
#            ...
# -1       0.000041
#  1958    0.000021
#  1952    0.000021
#  1964    0.000021
#  1959    0.000021
# Name: proportion, Length: 64, dtype: float64
# ___________________________________________________
# zip_2dig
# 13    0.077818
# 4     0.057043
# 3     0.044755
# 9     0.042310
# 89    0.039947
#         ...
# 33    0.000308
# 77    0.000267
# 48    0.000226
# 46    0.000103
# 0     0.000082
# Name: proportion, Length: 98, dtype: float64
# ___________________________________________________
# vl_advertise
# 34900.0     0.012946
# 33900.0     0.012000
# 39900.0     0.011898
# 35900.0     0.010665
# 36900.0     0.010459
#               ...
# 67200.0     0.000021
# 65790.0     0.000021
# 252490.0    0.000021
# 122800.0    0.000021
# 151990.0    0.000021
# Name: proportion, Length: 4217, dtype: float64
# ___________________________________________________
# n_photos
# 8     0.539279
# 7     0.147149
# 6     0.101408
# 5     0.068838
# 4     0.038118
# 0     0.035200
# 1     0.033063
# 3     0.019069
# 2     0.011548
# 9     0.004007
# 10    0.001048
# 11    0.000493
# 12    0.000288
# 16    0.000123
# 13    0.000103
# 17    0.000103
# 14    0.000062
# 20    0.000041
# 15    0.000021
# 18    0.000021
# 19    0.000021
# Name: proportion, dtype: float64
# ___________________________________________________
# km_vehicle
# 0         0.063824
# 100       0.029754
# 80000     0.009288
# 100000    0.009226
# 90000     0.008322
#             ...
# 31165     0.000021
# 135150    0.000021
# 10205     0.000021
# 98091     0.000021
# 91222     0.000021
# Name: proportion, Length: 15141, dtype: float64
# ___________________________________________________
# vl_market
# 41933.86353     0.000353
# 32483.37095     0.000330
# 25326.91660     0.000306
# 24534.09160     0.000283
# 46316.41582     0.000283
#                   ...
# 296682.10440    0.000024
# 32879.32766     0.000024
# 38040.18830     0.000024
# 22490.91919     0.000024
# 33437.95609     0.000024
# Name: proportion, Length: 36130, dtype: float64
# ___________________________________________________
# flg_single_owner
# 0    0.792911
# 1    0.207089
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_lincese
# 0    0.695901
# 1    0.304099
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_tax_paid
# 0    0.601233
# 1    0.398767
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_all_dealership_services
# 0    0.849687
# 1    0.150313
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_all_dealership_schedule_vehicle
# 0    0.933258
# 1    0.066742
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_factory_warranty
# 0    0.914764
# 1    0.085236
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_armored
# 0    0.979164
# 1    0.020836
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_trade_in
# 0    0.914477
# 1    0.085523
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_pcd
# 0    0.999589
# 1    0.000411
# Name: proportion, dtype: float64
# ___________________________________________________
# transmission_type
# manual                   0.555051
# automatico               0.428777
# CVT                      0.010418
# automatizado             0.002754
# semi-automatico          0.002548
# automatico sequencial    0.000226
# automatizado DCT         0.000226
# Name: proportion, dtype: float64
# ___________________________________________________
# n_doors
# 4.0    0.885870
# 2.0    0.078559
# 0.0    0.026714
# 3.0    0.008857
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_alarm
# 1    0.619706
# 0    0.380294
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_airbag
# 1    0.675311
# 0    0.324689
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_heater
# 1    0.633227
# 0    0.366773
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_leather_seats
# 0    0.671838
# 1    0.328162
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_air_conditioning
# 1    0.847139
# 0    0.152861
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_abs
# 1    0.633474
# 0    0.366526
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_rear_defogger
# 1    0.630165
# 0    0.369835
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_electric_locks
# 1    0.845002
# 0    0.154998
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_electric_windows
# 1    0.839679
# 0    0.160321
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_alloy_wheels
# 1    0.550622
# 0    0.449378
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_rain_sensor
# 0    0.91197
# 1    0.08803
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_parking_sensor
# 0    0.720497
# 1    0.279503
# Name: proportion, dtype: float64
# ___________________________________________________
# city
# São Paulo         0.187013
# Rio de Janeiro    0.045515
# Curitiba          0.041447
# Brasília          0.035981
# Belo Horizonte    0.029385
#                     ...
# Bom Retiro        0.000021
# Mandaguari        0.000021
# Itirapina         0.000021
# Iporá             0.000021
# Osazca            0.000021
# Name: proportion, Length: 959, dtype: float64
# ___________________________________________________
# state
# SP     0.470934
# PR     0.091236
# SC     0.077263
# RJ     0.076379
# MG     0.066639
# RS     0.053611
# DF     0.036125
# GO     0.019131
# PE     0.015843
# BA     0.012987
# MS     0.011363
# RN     0.010891
# CE     0.010767
# ES     0.009699
# MT     0.008404
# PB     0.004849
# MA     0.004767
# PA     0.003719
# RO     0.003370
# AM     0.003247
# PI     0.003000
# SE     0.002445
# AL     0.001644
# AC     0.000658
# AP     0.000370
# RR     0.000308
# TO     0.000267
# N/A    0.000082
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_alcool
# 1    0.730361
# 0    0.269639
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_gasolina
# 1    0.941457
# 0    0.058543
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_diesel
# 0    0.944868
# 1    0.055132
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_eletrico
# 0    0.999404
# 1    0.000596
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_benzina
# 0    0.999836
# 1    0.000164
# Name: proportion, dtype: float64
# ___________________________________________________
# flg_gas_natural
# 0    0.993548
# 1    0.006452
# Name: proportion, dtype: float64
# ___________________________________________________

# %% [markdown]
# ### Drop Duplicated Rows

# %%
df_processed = df_processed.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Clean Sporious Reading

# %%
df_processed = df_processed[~(df_processed == -1).any(axis=1)].reset_index(drop=True)

# %% [markdown]
# ### Creating a Lead flag columns

# %% [markdown]
#  - The findings until now we have the target proportion, showing that 78% of the advertisers have some lead.

# %%
df_processed['flg_leads'] = df_processed['leads'].apply(lambda x: 1 if x > 0 else 0)
df_processed.flg_leads.value_counts(normalize=True)
# Out:
# flg_leads
# 1    0.781497
# 0    0.218503
# Name: proportion, dtype: float64

# %% [markdown]
# # Check Features Relation

# %%
# Split columns into numeric and categorical
cat_cols = []
num_cols = []
for col in df_processed.columns:
    if any(prefix in col for prefix in ['cd_', 'zip_', 'year_','flg_', 'type', 'city','state']):
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
# Convert all numerical columns to absolute values
for col in num_cols:
    df_processed[col] = df_processed[col].abs()

# %% [markdown]
# ## Correlation (Numerical Features)
#
# - No strengh correlation found between numerical features and target **leads**. The only feature that shows some relevant correlation with the **leads** is the feature **phone_clicks**.

# %%
# Compute and display the correlation matrix for numerical columns
corr_matrix = df_processed[num_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
def summarize_numerical_features(df, cols, target_col=None):
    num_cols = [col for col in cols if col != target_col]

    summary = df[num_cols].describe().T
    summary['skew'] = df[num_cols].skew()
    summary['missing_pct'] = df[num_cols].isnull().mean() * 100
    
    if target_col:
        summary['corr_with_target'] = df[num_cols].corrwith(df[target_col])
        return summary.sort_values(by='corr_with_target', ascending=False)
    else:
        return summary

numerical_summary = summarize_numerical_features(df_processed, cols=num_cols, target_col='leads')
display(numerical_summary)
# Out:
#                 count           mean           std         min          25%  \
# phone_clicks  48663.0       7.467604  1.144856e+01     0.00000      2.00000
# n_photos      48663.0       6.625938  2.170149e+00     0.00000      6.00000
# vl_market     42448.0   52757.148739  4.160908e+04  6292.84354  31371.48076
# km_vehicle    48663.0  379012.801122  2.012781e+07     0.00000  29000.00000
# vl_advertise  48663.0  109282.201182  2.866440e+06     0.00000  30490.00000
# n_doors       48662.0       3.727241  8.221901e-01     0.00000      4.00000
# views         48663.0     446.344759  1.105268e+03     0.00000     76.00000
# priority      48663.0       2.601422  7.677747e-01     1.00000      3.00000
#
#                        50%           75%           max       skew  \
# phone_clicks      4.000000      9.000000  4.570000e+02   7.992176
# n_photos          8.000000      8.000000  2.000000e+01  -1.678831
# vl_market     40668.754055  61538.683182  1.111216e+06   4.894885
# km_vehicle    57000.000000  90000.000000  2.147484e+09  78.186831
# vl_advertise  41000.000000  64889.000000  4.050000e+08  86.780499
# n_doors           4.000000      4.000000  4.000000e+00  -3.190829
# views           196.000000    452.000000  9.360800e+04  31.923298
# priority          3.000000      3.000000  3.000000e+00  -1.501841
#
#               missing_pct  corr_with_target
# phone_clicks     0.000000          0.807339
# n_photos         0.000000          0.059248
# vl_market       12.771510          0.043609
# km_vehicle       0.000000          0.001584
# vl_advertise     0.000000         -0.001851
# n_doors          0.002055         -0.041346
# views            0.000000         -0.060004
# priority         0.000000         -0.147394

# %%
# Several variables (vl_advertise, km_vehicle, views) show extreme right-skew, indicating the presence of outliers or highly unbalanced behaviors.
# Negatively skewed features (n_photos, n_doors, priority) suggest strong user preferences or platform defaults that create dominant modes.
numerical_summary["skew"]
# Out:
# phone_clicks     7.992176
# n_photos        -1.678831
# vl_market        4.894885
# km_vehicle      78.186831
# vl_advertise    86.780499
# n_doors         -3.190829
# views           31.923298
# priority        -1.501841
# Name: skew, dtype: float64

# %%
df_processed[num_cols].plot(kind='kde', subplots=True, layout=(3, 3), figsize=(15, 10), sharex=False)
plt.suptitle('KDE Plots of Numerical Features', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outliers Analysis

# %%
n_cols = len(num_cols)
fig, axes = plt.subplots(1, n_cols, figsize=(n_cols*4, 5), constrained_layout=True)

for i, col in enumerate(num_cols):
    ax = axes[i] if n_cols > 1 else axes
    sns.boxplot(data=df_processed, x=col, ax=ax)
    ax.set_title(f'Boxplot of {col}')
    ax.set_xlabel(col)

plt.suptitle('Boxplots of Numerical Features', fontsize=16, y=1.02)
plt.show()

# %%
def remove_outliers_iqr(df, columns, k=1.5):
    df_clean = df.copy()
    for col in columns:
        q1 = df[col].quantile(0.01)
        q3 = df[col].quantile(0.995)
        iqr = q3 - q1
        lower = q1 - k * iqr
        upper = q3 + k * iqr
        print(f"Removing outliers for {col}: IQR = {iqr}, lower bound = {lower}, upper bound = {upper}")
        df_clean = df_clean[(df_clean[col] >= lower) & (df_clean[col] <= upper)]
    return df_clean

df_clean = remove_outliers_iqr(df_processed, num_cols).reset_index(drop=True)

fig, axes = plt.subplots(1, n_cols, figsize=(n_cols*4, 5), constrained_layout=True)

for i, col in enumerate(num_cols):
    ax = axes[i] if n_cols > 1 else axes
    sns.boxplot(data=df_clean, x=col, ax=ax)
    ax.set_title(f'Boxplot of {col}')
    ax.set_xlabel(col)

plt.suptitle('Boxplots of Numerical Features', fontsize=16, y=1.02)
plt.show()
# Out:
# Removing outliers for priority: IQR = 2.0, lower bound = -2.0, upper bound = 6.0
# Removing outliers for leads: IQR = 72.0, lower bound = -108.0, upper bound = 180.0
# Removing outliers for views: IQR = 5371.280000000028, lower bound = -8055.920000000042, upper bound = 13429.20000000007
# Removing outliers for phone_clicks: IQR = 70.0, lower bound = -105.0, upper bound = 175.0
# Removing outliers for vl_advertise: IQR = 377114.42, lower bound = -553786.05, upper bound = 954671.63
# Removing outliers for n_photos: IQR = 9.0, lower bound = -13.5, upper bound = 22.5
# Removing outliers for km_vehicle: IQR = 999999.0, lower bound = -1499998.5, upper bound = 2499997.5
# Removing outliers for vl_market: IQR = 278942.4406526992, lower bound = -404570.25686524884, upper bound = 711199.505745548
# Removing outliers for n_doors: IQR = 4.0, lower bound = -6.0, upper bound = 10.0

# %%
numerical_summary = summarize_numerical_features(df_clean, cols=num_cols, target_col='leads')
display(numerical_summary)
# Out:
#                 count          mean           std         min          25%  \
# phone_clicks  42354.0      6.899348      9.661037     0.00000      2.00000
# n_photos      42354.0      6.682391      2.133324     0.00000      6.00000
# vl_market     42354.0  52694.986633  40912.285450  6292.84354  31371.48076
# vl_advertise  42354.0  52314.196154  40971.656726  4900.00000  30900.00000
# km_vehicle    42354.0  69809.883624  82153.276127     0.00000  34000.00000
# n_doors       42354.0      3.779501      0.735668     0.00000      4.00000
# views         42354.0    452.337630    811.722499     0.00000     84.00000
# priority      42354.0      2.607050      0.764955     1.00000      3.00000
#
#                       50%           75%           max      skew  missing_pct  \
# phone_clicks      4.00000      8.000000  1.690000e+02  4.988847          0.0
# n_photos          8.00000      8.000000  2.000000e+01 -1.757777          0.0
# vl_market     40666.11223  61527.702695  6.922326e+05  4.353576          0.0
# vl_advertise  39990.00000  60900.000000  7.500000e+05  4.399426          0.0
# km_vehicle    59323.00000  89500.000000  1.320000e+06  8.179254          0.0
# n_doors           4.00000      4.000000  4.000000e+00 -3.586303          0.0
# views           208.00000    472.000000  1.304800e+04  5.675769          0.0
# priority          3.00000      3.000000  3.000000e+00 -1.524367          0.0
#
#               corr_with_target
# phone_clicks          0.774714
# n_photos              0.064755
# vl_market             0.050552
# vl_advertise          0.033426
# km_vehicle           -0.026348
# n_doors              -0.042511
# views                -0.084602
# priority             -0.167694

# %% [markdown]
# ## Categorical Features Calssification

# %% [markdown]
# - This type of analysis is essential to understand what kind of categorical variables we are dealing with and how to properly use them in model development.
#
# - Categorical variables often contain a large number of unique classes — for example, a variable like city can have hundreds of distinct locations. Feeding such high-granularity variables directly into the model may not be effective.
#
# - High cardinality or high granularity can bias the model. In such cases, the model might learn to always give the same prediction for a specific class (e.g., always output a high lead count for a particular city), regardless of other features. This happens because the model assigns disproportionate importance to the most frequent or highly specific categories, reducing generalization and increasing the risk of overfitting.

# %%
# This is an important step of the EDA process, as it helps to understand the nature of 
# categorical features in the dataset. We will classify categorical features into:
# - Binary: Features with exactly two unique values (e.g., Yes/No, True/False).
# - Nominal (Low Cardinality): Features with a small number of unique values (e.g., colors, types).
# - Nominal (Medium Cardinality): Features with a moderate number of unique values (e.g., cities, brands).
# - Nominal (High Cardinality): Features with a large number of unique values (e.g., user IDs, product codes).  

cat_cols.append("priority")


def classify_categorical_features(
    df,
    cols,
    threshold_low=15,
    threshold_high=50,
    id_keywords=["id", "cd_", "code"],
):
    result = []

    for col in cols:
        if (
            df[col].dtype == "object" or df[col].nunique() < 1000
        ):  
            nunique = df[col].nunique()
            col_lower = col.lower()

            if nunique == 2:
                category_type = "binary"
            elif any(key in col_lower for key in id_keywords):
                category_type = "identity/high cardinality"
            elif nunique <= threshold_low:
                category_type = "nominal (low cardinality)"
            elif nunique <= threshold_high:
                category_type = "nominal (medium cardinality)"
            else:
                category_type = "nominal (high cardinality)"

            result.append(
                {
                    "feature": col,
                    "dtype": str(df[col].dtype),
                    "n_unique": nunique,
                    "category_type": category_type,
                }
            )

    return pd.DataFrame(result).sort_values(by="category_type")


summary = classify_categorical_features(df_clean, cols=cat_cols)
summary
# Out:
#                                 feature   dtype  n_unique  \
# 0                    cd_type_individual   int64         2
# 19                 flg_air_conditioning   int64         2
# 20                              flg_abs   int64         2
# 21                    flg_rear_defogger   int64         2
# 22                   flg_electric_locks   int64         2
# 23                 flg_electric_windows   int64         2
# 24                     flg_alloy_wheels   int64         2
# 35                            flg_leads   int64         2
# 25                      flg_rain_sensor   int64         2
# 29                           flg_alcool   int64         2
# 30                         flg_gasolina   int64         2
# 31                           flg_diesel   int64         2
# 32                         flg_eletrico   int64         2
# 33                          flg_benzina   int64         2
# 34                      flg_gas_natural   int64         2
# 26                   flg_parking_sensor   int64         2
# 17                           flg_heater   int64         2
# 18                    flg_leather_seats   int64         2
# 15                            flg_alarm   int64         2
# 13                              flg_pcd   int64         2
# 12                         flg_trade_in   int64         2
# 11                          flg_armored   int64         2
# 10                 flg_factory_warranty   int64         2
# 9   flg_all_dealership_schedule_vehicle   int64         2
# 8           flg_all_dealership_services   int64         2
# 7                          flg_tax_paid   int64         2
# 16                           flg_airbag   int64         2
# 6                           flg_lincese   int64         2
# 5                      flg_single_owner   int64         2
# 1                      cd_vehicle_brand   int64        44
# 2                      cd_model_vehicle   int64       431
# 27                                 city  object       873
# 4                              zip_2dig   int64        97
# 14                    transmission_type  object         7
# 36                             priority   int64         3
# 3                            year_model   int64        45
# 28                                state  object        27
#
#                    category_type
# 0                         binary
# 19                        binary
# 20                        binary
# 21                        binary
# 22                        binary
# 23                        binary
# 24                        binary
# 35                        binary
# 25                        binary
# 29                        binary
# 30                        binary
# 31                        binary
# 32                        binary
# 33                        binary
# 34                        binary
# 26                        binary
# 17                        binary
# 18                        binary
# 15                        binary
# 13                        binary
# 12                        binary
# 11                        binary
# 10                        binary
# 9                         binary
# 8                         binary
# 7                         binary
# 16                        binary
# 6                         binary
# 5                         binary
# 1      identity/high cardinality
# 2      identity/high cardinality
# 27    nominal (high cardinality)
# 4     nominal (high cardinality)
# 14     nominal (low cardinality)
# 36     nominal (low cardinality)
# 3   nominal (medium cardinality)
# 28  nominal (medium cardinality)

# %% [markdown]
# ## Bivariate Analysis

# %%
df_biv = df_clean.copy()
dfs_bivariate = {}

for col in cat_cols:
    grouped = (
        df_biv.groupby(col)['leads']
        .agg(
            count='count',
            mean_leads='mean',
            sum_leads='sum'
        )
        .sort_values(by='mean_leads', ascending=False)
        .reset_index()
    )
    grouped['percentage'] = (grouped['count'] / grouped['count'].sum()) * 100
    dfs_bivariate[col] = grouped

# %%
for keys in dfs_bivariate.keys():
    if keys.startswith('flg_') or keys.startswith('cd_'):
        continue
    else:
        print(f"Top 10 categories for {keys}:")
        display(dfs_bivariate[keys].sort_values(by='sum_leads', ascending=False).head(10))
        print("\n")
# Out:
# Top 10 categories for year_model:
#     year_model  count  mean_leads  sum_leads  percentage
# 23        2015   5942    3.850892      22882   14.029371
# 22        2014   5529    3.922409      21687   13.054257
# 19        2013   4770    4.285744      20443   11.262218
# 16        2012   3700    4.419189      16351    8.735893
# 26        2016   4875    3.312410      16148   11.510129
# 24        2017   4129    3.748123      15476    9.748784
# 18        2011   2845    4.373989      12444    6.717193
# 27        2018   3618    3.221669      11656    8.542286
# 14        2010   2029    4.712173       9561    4.790575
# 15        2009   1448    4.674724       6769    3.418803
# Top 10 categories for zip_2dig:
#     zip_2dig  count  mean_leads  sum_leads  percentage
# 2          4   2367    9.327841      22079    5.588610
# 4          3   1887    8.679915      16379    4.455305
# 11        13   3476    4.254315      14788    8.207017
# 1          5   1346   10.465082      14086    3.177976
# 3          2   1304    9.028374      11773    3.078812
# 5          9   1806    6.084718      10989    4.264060
# 7          6   1053    5.105413       5376    2.486188
# 10        15   1003    4.679960       4694    2.368135
# 9         22    804    4.782338       3845    1.898286
# 0          1    336   10.511905       3532    0.793314
# Top 10 categories for transmission_type:
#        transmission_type  count  mean_leads  sum_leads  percentage
# 3             automatico  17866    4.865443      86926   42.182557
# 5                 manual  23854    3.301668      78758   56.320536
# 1                    CVT    404   10.175743       4111    0.953865
# 2           automatizado     98    6.836735        670    0.231383
# 6        semi-automatico    115    2.791304        321    0.271521
# 0       automatizado DCT     10   20.100000        201    0.023611
# 4  automatico sequencial      7    4.142857         29    0.016527
# Top 10 categories for city:
#                       city  count  mean_leads  sum_leads  percentage
# 32               São Paulo   7576    9.194958      69661   17.887331
# 94          Rio de Janeiro   1892    4.382135       8291    4.467111
# 71                Campinas   1193    5.403185       6446    2.816735
# 61   São Bernardo do Campo    728    6.072802       4421    1.718846
# 150         Belo Horizonte   1216    3.598684       4376    2.871039
# 66             Santo André    659    5.792109       3817    1.555933
# 292               Curitiba   1846    2.035211       3757    4.358502
# 270               Brasília   1490    2.210067       3293    3.517968
# 75   São José do Rio Preto    609    5.088670       3099    1.437881
# 87                  Osasco    564    4.530142       2555    1.331633
# Top 10 categories for state:
#    state  count  mean_leads  sum_leads  percentage
# 0     SP  19818    6.117419     121235   46.791330
# 2     RJ   3157    3.597719      11358    7.453841
# 13    PR   4023    1.813075       7294    9.498513
# 4     MG   2699    2.664691       7192    6.372480
# 18    SC   3555    1.682700       5982    8.393540
# 17    RS   2220    1.696396       3766    5.241536
# 8     DF   1497    2.205077       3301    3.534495
# 3     GO    754    2.672414       2015    1.780233
# 5     BA    557    2.418312       1347    1.315106
# 6     RN    500    2.278000       1139    1.180526
# Top 10 categories for priority:
#    priority  count  mean_leads  sum_leads  percentage
# 2         3  33051    3.051980     100871   78.035132
# 1         1   7340    6.896049      50617   17.330122
# 0         2   1963    9.948039      19528    4.634745

# %%
def plot_top_categories(col_name, metric='sum_leads', top_n=10):
    df_plot = dfs_bivariate[col_name].sort_values(by=metric, ascending=False).head(top_n)
    sns.barplot(x=metric, y=col_name, data=df_plot)
    plt.title(f"{col_name} - Top {top_n} by {metric}")
    plt.show()

plot_top_categories('city')

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ### Numerical Columns

# %%
def binned_target_analysis(df, feature, target, bins=10):
    df_cut = pd.cut(df[feature], bins=bins)
    return df.groupby(df_cut)[target].agg(['count']).sort_index()

higher_bin = {}
for col in num_cols:
    if col != 'leads':
        binned_analysis = binned_target_analysis(df_clean, col, 'leads', bins=10)
        higher_bin[col] = {"max": binned_analysis['count'].max(),
                           "proportion_max": binned_analysis['count'].max() / binned_analysis['count'].sum(),
                           "min": binned_analysis['count'].min(),
                           "bin_counts": binned_analysis['count'].idxmax()}
higher_bin
# Out:
# {'priority': {'max': 33051,
#   'proportion_max': 0.7803513245502196,
#   'min': 0,
#   'bin_counts': Interval(2.8, 3.0, closed='right')},
#  'views': {'max': 39199,
#   'proportion_max': 0.9255088067242764,
#   'min': 10,
#   'bin_counts': Interval(-13.048, 1304.8, closed='right')},
#  'phone_clicks': {'max': 38884,
#   'proportion_max': 0.9180714926571281,
#   'min': 3,
#   'bin_counts': Interval(-0.169, 16.9, closed='right')},
#  'vl_advertise': {'max': 36283,
#   'proportion_max': 0.8566605279312461,
#   'min': 3,
#   'bin_counts': Interval(4154.9, 79410.0, closed='right')},
#  'n_photos': {'max': 29628,
#   'proportion_max': 0.6995325116872079,
#   'min': 2,
#   'bin_counts': Interval(6.0, 8.0, closed='right')},
#  'km_vehicle': {'max': 39209,
#   'proportion_max': 0.9257449119327572,
#   'min': 1,
#   'bin_counts': Interval(-1320.0, 132000.0, closed='right')},
#  'vl_market': {'max': 35166,
#   'proportion_max': 0.8302875761439298,
#   'min': 4,
#   'bin_counts': Interval(5606.904, 74886.821, closed='right')},
#  'n_doors': {'max': 38358,
#   'proportion_max': 0.9056523586910328,
#   'min': 0,
#   'bin_counts': Interval(3.6, 4.0, closed='right')}}

# %%
num_cols.remove('priority')

# %%
import xgboost as xgb
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

df = df_clean.copy()

df[num_cols] = df[num_cols].fillna(0)

cols_ = [
    "views",
    "phone_clicks",
    "vl_advertise",
    "n_photos",
    "km_vehicle",
    "vl_market",
    "n_doors"
]  

X = df[cols_]
y = df["flg_leads"] 

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)


model = xgb.XGBClassifier(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.01,
    random_state=42,
    tree_method="auto",  # fast on large datasets
)

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
importances = model.get_booster().get_score(importance_type='gain')
feature_importance_df = pd.DataFrame({
    'feature': list(importances.keys()),
    'importance_gain': list(importances.values())
}).sort_values(by='importance_gain', ascending=False)

display(feature_importance_df.head(10))
# Out:
#         feature  importance_gain
# 1  phone_clicks        45.263588
# 0         views         3.876415
# 3      n_photos         3.683598
# 2  vl_advertise         3.484506
# 5     vl_market         3.413781
# 4    km_vehicle         3.373738
# 6       n_doors         2.347659

# %%
import shap

explainer = shap.Explainer(model)
shap_values = explainer(X_train)
shap.plots.beeswarm(shap_values)  # Beeswarm plot for feature importance

# %% [markdown]
# ### Categorical Columns

# %%
cat_cols
# Out:
# ['cd_advertise',
#  'cd_client',
#  'cd_type_individual',
#  'cd_vehicle_brand',
#  'cd_model_vehicle',
#  'cd_version_vehicle',
#  'year_model',
#  'zip_2dig',
#  'flg_single_owner',
#  'flg_lincese',
#  'flg_tax_paid',
#  'flg_all_dealership_services',
#  'flg_all_dealership_schedule_vehicle',
#  'flg_factory_warranty',
#  'flg_armored',
#  'flg_trade_in',
#  'flg_pcd',
#  'transmission_type',
#  'flg_alarm',
#  'flg_airbag',
#  'flg_heater',
#  'flg_leather_seats',
#  'flg_air_conditioning',
#  'flg_abs',
#  'flg_rear_defogger',
#  'flg_electric_locks',
#  'flg_electric_windows',
#  'flg_alloy_wheels',
#  'flg_rain_sensor',
#  'flg_parking_sensor',
#  'city',
#  'state',
#  'flg_alcool',
#  'flg_gasolina',
#  'flg_diesel',
#  'flg_eletrico',
#  'flg_benzina',
#  'flg_gas_natural',
#  'flg_leads',
#  'priority']

# %%
cat_cols_ = [
#  'cd_type_individual',
#  'cd_vehicle_brand',
#  'cd_model_vehicle',
#  'cd_version_vehicle',
#  'year_model',
#  'zip_2dig',
 'flg_single_owner',
 'flg_lincese',
 'flg_tax_paid',
 'flg_all_dealership_services',
 'flg_all_dealership_schedule_vehicle',
 'flg_factory_warranty',
 'flg_armored',
 'flg_trade_in',
 'flg_pcd',
#  'transmission_type',
 'flg_alarm',
 'flg_airbag',
 'flg_heater',
 'flg_leather_seats',
 'flg_air_conditioning',
 'flg_abs',
 'flg_rear_defogger',
 'flg_electric_locks',
 'flg_electric_windows',
 'flg_alloy_wheels',
 'flg_rain_sensor',
 'flg_parking_sensor',
#  'city',
 'state',
 'flg_alcool',
 'flg_gasolina',
 'flg_diesel',
 'flg_eletrico',
 'flg_benzina',
 'flg_gas_natural',
#  'priority'
]

# %%
df = df_clean.copy()

encoder = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
df[cat_cols_] = encoder.fit_transform(df[cat_cols_])

X = df[cat_cols_]
y = df["flg_leads"] 

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)


model = xgb.XGBClassifier(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.001,
    random_state=42,
    tree_method="auto",  # fast on large datasets
)

model.fit(X_train, y_train)


importances = model.get_booster().get_score(importance_type='gain')
feature_importance_df = pd.DataFrame({
    'feature': list(importances.keys()),
    'importance_gain': list(importances.values())
}).sort_values(by='importance_gain', ascending=False)

display(feature_importance_df.head(10))
# Out:
#                                 feature  importance_gain
# 1                           flg_lincese        22.337120
# 8                             flg_alarm        17.470959
# 20                                state        15.200387
# 22                         flg_gasolina         8.769967
# 2                          flg_tax_paid         8.335808
# 4   flg_all_dealership_schedule_vehicle         7.863601
# 15                   flg_electric_locks         4.890680
# 19                   flg_parking_sensor         4.530205
# 9                            flg_airbag         4.321956
# 7                          flg_trade_in         3.931312

# %%
import shap

explainer = shap.Explainer(model)
shap_values = explainer(X_train)
shap.plots.beeswarm(shap_values)  # Beeswarm plot for feature importance
